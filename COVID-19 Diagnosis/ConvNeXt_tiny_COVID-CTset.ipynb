# %% [markdown]
# ### Setup

# %%
from google.colab import drive 
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/ /mydrive
# Out:
# Mounted at /content/gdrive

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2370003786156096879
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14465892352
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 14123327189522299920
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
#  xla_global_id: 416903419]

# %%
# !pip -q install timm
# Out:
#      |████████████████████████████████| 431 kB 8.6 MB/s

# %%
from __future__ import print_function

import glob
from itertools import chain
import time
import os
import random
import zipfile
import copy

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from PIL import Image
from sklearn.model_selection import train_test_split
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from tqdm.notebook import tqdm

import timm

# %config InlineBackend.figure_format = 'retina'

# %%
print(f"Torch: {torch.__version__}")
# Out:
# Torch: 1.10.0+cu111

# %% [markdown]
# ### Dataset Setup

# %%
# !unzip '/content/gdrive/MyDrive/Dataset/COVID-CTset/Train&Validation.zip' -d '/content/data'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/data/normal2_patient329_SR_2_IM00024.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00025.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00026.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00028.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00029.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00030.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00031.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00032.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00033.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00034.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00035.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00036.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00037.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00038.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00039.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00040.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00041.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00042.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00043.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00044.tif
#   inflating: /content/data/normal2_patient329_SR_2_IM00045.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00006.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00007.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00008.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00009.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00010.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00011.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00012.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00013.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00014.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00015.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00016.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00017.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00024.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00025.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00026.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00027.tif
#   inflating: /content/data/normal2_patient331_SR_2_IM00028.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00011.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00012.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00013.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00014.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00015.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00016.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00017.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00018.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00019.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00020.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00021.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00029.tif
#   inflating: /content/data/normal2_patient332_SR_2_IM00030.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00006.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00007.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00008.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00009.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00010.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00011.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00012.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00013.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00014.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00015.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00016.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00017.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00018.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00026.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00027.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00028.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00029.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00030.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00031.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00032.tif
#   inflating: /content/data/normal2_patient333_SR_2_IM00033.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00006.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00007.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00008.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00009.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00010.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00011.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00012.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00013.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00014.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00015.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00016.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00017.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00018.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00019.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00020.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00021.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00022.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00023.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00024.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00025.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00026.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00027.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00028.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00029.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00030.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00031.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00032.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00033.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00034.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00035.tif
#   inflating: /content/data/normal2_patient334_SR_2_IM00036.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00008.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00009.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00010.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00011.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00012.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00013.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00014.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00015.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00028.tif
#   inflating: /content/data/normal2_patient335_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00004.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient336_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00004.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient337_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00032.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00033.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00034.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00035.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00036.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00037.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00038.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00039.tif
#   inflating: /content/data/normal3_patient338_SR_2_IM00040.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00004.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient339_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00032.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00033.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00034.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00035.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00036.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00037.tif
#   inflating: /content/data/normal3_patient340_SR_2_IM00038.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00004.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient341_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00003.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00004.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient342_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient343_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00032.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00033.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00034.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00035.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00036.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00037.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00038.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00039.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00040.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00041.tif
#   inflating: /content/data/normal3_patient344_SR_2_IM00042.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00032.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00033.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00034.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00035.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00036.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00037.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00038.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00039.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00040.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00041.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00042.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00043.tif
#   inflating: /content/data/normal3_patient345_SR_2_IM00044.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient346_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient347_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient348_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient348_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient348_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient348_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient348_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient348_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient348_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient348_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient348_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00032.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00033.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00034.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00035.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00036.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00037.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00038.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00039.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00040.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00041.tif
#   inflating: /content/data/normal3_patient349_SR_2_IM00042.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00032.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00033.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00034.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00035.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00036.tif
#   inflating: /content/data/normal3_patient350_SR_2_IM00037.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00004.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient351_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00032.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00033.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00034.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00035.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00036.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00037.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00038.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00039.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00040.tif
#   inflating: /content/data/normal3_patient352_SR_2_IM00041.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00004.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient354_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00032.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00033.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00034.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00035.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00036.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00037.tif
#   inflating: /content/data/normal3_patient355_SR_2_IM00038.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00003.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00004.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient356_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00005.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient358_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00006.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient359_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00007.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00008.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00009.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00010.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00011.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00012.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00013.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00014.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00015.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00016.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00017.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00018.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00019.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00020.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00021.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00022.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00023.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00024.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00025.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00026.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00027.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00028.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00029.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00030.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00031.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00032.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00033.tif
#   inflating: /content/data/normal3_patient360_SR_2_IM00034.tif
# ...
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00019.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00020.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00021.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00022.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00023.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00024.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00025.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00026.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00027.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00028.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00029.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00030.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00031.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00032.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00033.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00034.tif
#   inflating: /content/data/normalcd3_patient430_SR_2_IM00035.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00011.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00012.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00013.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00014.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00015.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00016.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00017.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00018.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00019.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00020.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00021.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00022.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00023.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00024.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00025.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00026.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00027.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00028.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00029.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00030.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00031.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00032.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00033.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00034.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00035.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00036.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00037.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00038.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00039.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00040.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00041.tif
#   inflating: /content/data/normalcd3_patient431_SR_2_IM00042.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00007.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00008.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00009.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00010.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00011.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00012.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00013.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00014.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00015.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00016.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00017.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00018.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00019.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00020.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00021.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00022.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00023.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00024.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00025.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00026.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00027.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00028.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00029.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00030.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00031.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00032.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00033.tif
#   inflating: /content/data/normalcd3_patient432_SR_2_IM00034.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00008.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00009.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00010.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00011.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00012.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00013.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00014.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00015.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00016.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00017.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00018.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00019.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00020.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00021.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00022.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00023.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00024.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00025.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00026.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00027.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00028.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00029.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00030.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00031.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00032.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00033.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00034.tif
#   inflating: /content/data/normalcd3_patient433_SR_2_IM00035.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00008.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00009.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00010.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00011.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00012.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00013.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00014.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00015.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00016.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00017.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00018.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00019.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00020.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00021.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00022.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00023.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00024.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00025.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00026.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00027.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00028.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00029.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00030.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00031.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00032.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00033.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00034.tif
#   inflating: /content/data/normalcd3_patient434_SR_2_IM00035.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00010.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00011.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00012.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00013.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00014.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00015.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00016.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00017.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00018.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00019.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00020.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00022.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00023.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00024.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00025.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00026.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00027.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00028.tif
#   inflating: /content/data/137covid_patient1_SR_2_IM00029.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00011.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00012.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00013.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00014.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00015.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00017.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00018.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00019.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00020.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00022.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00023.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00024.tif
#   inflating: /content/data/137covid_patient1_SR_3_IM00027.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00055.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00056.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00057.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00058.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00059.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00060.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00061.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00062.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00063.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00064.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00074.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00075.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00076.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00081.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00082.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00083.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00084.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00085.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00086.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00087.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00088.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00089.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00090.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00091.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00092.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00110.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00111.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00112.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00113.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00114.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00115.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00116.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00117.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00118.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00119.tif
#   inflating: /content/data/137covid_patient1_SR_4_IM00120.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00012.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00013.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00014.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00015.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00016.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00018.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00019.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00020.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00021.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00022.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00023.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00024.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00025.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00026.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00028.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00029.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00030.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00032.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00033.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00034.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00035.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00036.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00037.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00038.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00039.tif
#   inflating: /content/data/137covid_patient3_SR_2_IM00040.tif
#   inflating: /content/data/137covid_patient3_SR_3_IM00020.tif
#   inflating: /content/data/137covid_patient3_SR_4_IM00015.tif
#   inflating: /content/data/137covid_patient3_SR_4_IM00022.tif
#   inflating: /content/data/137covid_patient3_SR_4_IM00025.tif
#   inflating: /content/data/137covid_patient3_SR_4_IM00026.tif
#   inflating: /content/data/137covid_patient5_SR_2_IM00036.tif
#   inflating: /content/data/137covid_patient5_SR_3_IM00017.tif
#   inflating: /content/data/137covid_patient7_SR_2_IM00009.tif
#   inflating: /content/data/137covid_patient7_SR_2_IM00010.tif
#   inflating: /content/data/137covid_patient7_SR_2_IM00011.tif
#   inflating: /content/data/137covid_patient7_SR_2_IM00012.tif
#   inflating: /content/data/137covid_patient7_SR_2_IM00013.tif
#   inflating: /content/data/137covid_patient7_SR_2_IM00015.tif
#   inflating: /content/data/137covid_patient7_SR_2_IM00016.tif
#   inflating: /content/data/137covid_patient7_SR_2_IM00020.tif
#   inflating: /content/data/137covid_patient7_SR_2_IM00021.tif

# %%
import pandas as pd
train1 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/train1.csv')
train2 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/train2.csv')
train3 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/train3.csv')
train4 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/train4.csv')
train5 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/train5.csv')

train_df = pd.concat([train1, train2, train3, train4, train5])

test1 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/test1.csv')
test2 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/test2.csv')
test3 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/test3.csv')
test4 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/test4.csv')
test5 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/test5.csv')

test_df = pd.concat([test1, test2, test3, test4, test5])

val1 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/validation1.csv')
val2 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/validation2.csv')
val3 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/validation3.csv')
val4 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/validation4.csv')
val5 = pd.read_csv('/content/gdrive/MyDrive/Dataset/COVID-CTset/CSV/validation5.csv')

val_df = pd.concat([val1, val2, val3, val4, val5])

all_df = pd.concat([train_df, test_df, val_df])
all_df = all_df.drop_duplicates(subset=['filename', 'class'], keep='first')
all_df

# The csv files provided shows the dataset is used in 5 folds. 
# Therefore, there will be duplicates.
# We remove the duplicates here.
# Out:
#                                  filename   class
# 0      137covid_patient1_SR_2_IM00010.tif   covid
# 1      137covid_patient1_SR_2_IM00011.tif   covid
# 2      137covid_patient1_SR_2_IM00012.tif   covid
# 3      137covid_patient1_SR_2_IM00013.tif   covid
# 4      137covid_patient1_SR_2_IM00014.tif   covid
# ...                                   ...     ...
# 6598  normal5_patient194_SR_2_IM00036.tif  normal
# 6599  normal5_patient194_SR_2_IM00037.tif  normal
# 6600  normal5_patient194_SR_2_IM00038.tif  normal
# 6601  normal5_patient194_SR_2_IM00039.tif  normal
# 6602  normal5_patient194_SR_2_IM00040.tif  normal
#
# [12058 rows x 2 columns]

# %%
import pandas as pd
# df["class"].explode().unique() 
covid_df = all_df.loc[all_df['class'] == 'covid']
normal_df = all_df.loc[all_df['class'] == 'normal']
covid_files = covid_df['filename'].tolist()  # 2282
normal_files = normal_df['filename'].tolist()  # 9776

# %%
# !mkdir '/content/dataset'
# !mkdir '/content/dataset/Covid'
# !mkdir '/content/dataset/Normal'

# %%
import shutil
import os
    
source_dir = '/content/data'
covid_dir = '/content/dataset/Covid'
    
for file_name in covid_files:
    shutil.move(os.path.join(source_dir, file_name), covid_dir)

source_dir = '/content/data'
normal_dir = '/content/dataset/Normal'
    
for file_name in normal_files:
    shutil.move(os.path.join(source_dir, file_name), normal_dir)

# %%
# !rm -r /content/data

# %% [markdown]
# ### Load Data and Configure Training settings

# %%
# Training settings
batch_size = 32
epochs = 20
lr = 3e-5
gamma = 0.7
seed = 42

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

seed_everything(seed)

# %%
TRANSFORM_IMG = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406],
    #                      std=[0.229, 0.224, 0.225] )
    ])

# %%
import torchvision
from torchvision.transforms import ToTensor

full_data = torchvision.datasets.ImageFolder('/content/dataset/', transform=TRANSFORM_IMG)
train_data, test_data, valid_data = torch.utils.data.random_split(full_data, [9646, 1206, 1206])

# %%
import torch.utils.data as data
from torch.autograd import Variable
import numpy as np

train_loader = data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
valid_loader = data.DataLoader(valid_data, batch_size=batch_size, shuffle=True)
test_loader  = data.DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %%
print(len(train_data), len(train_loader))
print(len(valid_data), len(valid_loader))
print(len(test_data), len(test_loader))
# Out:
# 9646 302
# 1206 38
# 1206 38

# %%
from pprint import pprint
model_names = timm.list_models(pretrained=True)
pprint(model_names)
# Out:
# ['adv_inception_v3',
#  'bat_resnext26ts',
#  'beit_base_patch16_224',
#  'beit_base_patch16_224_in22k',
#  'beit_base_patch16_384',
#  'beit_large_patch16_224',
#  'beit_large_patch16_224_in22k',
#  'beit_large_patch16_384',
#  'beit_large_patch16_512',
#  'botnet26t_256',
#  'cait_m36_384',
#  'cait_m48_448',
#  'cait_s24_224',
#  'cait_s24_384',
#  'cait_s36_384',
#  'cait_xs24_384',
#  'cait_xxs24_224',
#  'cait_xxs24_384',
#  'cait_xxs36_224',
#  'cait_xxs36_384',
#  'coat_lite_mini',
#  'coat_lite_small',
#  'coat_lite_tiny',
#  'coat_mini',
#  'coat_tiny',
#  'convit_base',
#  'convit_small',
#  'convit_tiny',
#  'convmixer_768_32',
#  'convmixer_1024_20_ks9_p14',
#  'convmixer_1536_20',
#  'convnext_base',
#  'convnext_base_384_in22ft1k',
#  'convnext_base_in22ft1k',
#  'convnext_base_in22k',
#  'convnext_large',
#  'convnext_large_384_in22ft1k',
#  'convnext_large_in22ft1k',
#  'convnext_large_in22k',
#  'convnext_small',
#  'convnext_tiny',
#  'convnext_xlarge_384_in22ft1k',
#  'convnext_xlarge_in22ft1k',
#  'convnext_xlarge_in22k',
#  'crossvit_9_240',
#  'crossvit_9_dagger_240',
#  'crossvit_15_240',
#  'crossvit_15_dagger_240',
#  'crossvit_15_dagger_408',
#  'crossvit_18_240',
#  'crossvit_18_dagger_240',
#  'crossvit_18_dagger_408',
#  'crossvit_base_240',
#  'crossvit_small_240',
#  'crossvit_tiny_240',
#  'cspdarknet53',
#  'cspresnet50',
#  'cspresnext50',
#  'deit_base_distilled_patch16_224',
#  'deit_base_distilled_patch16_384',
#  'deit_base_patch16_224',
#  'deit_base_patch16_384',
#  'deit_small_distilled_patch16_224',
#  'deit_small_patch16_224',
#  'deit_tiny_distilled_patch16_224',
#  'deit_tiny_patch16_224',
#  'densenet121',
#  'densenet161',
#  'densenet169',
#  'densenet201',
#  'densenetblur121d',
#  'dla34',
#  'dla46_c',
#  'dla46x_c',
#  'dla60',
#  'dla60_res2net',
#  'dla60_res2next',
#  'dla60x',
#  'dla60x_c',
#  'dla102',
#  'dla102x',
#  'dla102x2',
#  'dla169',
#  'dm_nfnet_f0',
#  'dm_nfnet_f1',
#  'dm_nfnet_f2',
#  'dm_nfnet_f3',
#  'dm_nfnet_f4',
#  'dm_nfnet_f5',
#  'dm_nfnet_f6',
#  'dpn68',
#  'dpn68b',
#  'dpn92',
#  'dpn98',
#  'dpn107',
#  'dpn131',
#  'eca_botnext26ts_256',
#  'eca_halonext26ts',
#  'eca_nfnet_l0',
#  'eca_nfnet_l1',
#  'eca_nfnet_l2',
#  'eca_resnet33ts',
#  'eca_resnext26ts',
#  'ecaresnet26t',
#  'ecaresnet50d',
#  'ecaresnet50d_pruned',
#  'ecaresnet50t',
#  'ecaresnet101d',
#  'ecaresnet101d_pruned',
#  'ecaresnet269d',
#  'ecaresnetlight',
#  'efficientnet_b0',
#  'efficientnet_b1',
#  'efficientnet_b1_pruned',
#  'efficientnet_b2',
#  'efficientnet_b2_pruned',
#  'efficientnet_b3',
#  'efficientnet_b3_pruned',
#  'efficientnet_b4',
#  'efficientnet_el',
#  'efficientnet_el_pruned',
#  'efficientnet_em',
#  'efficientnet_es',
#  'efficientnet_es_pruned',
#  'efficientnet_lite0',
#  'efficientnetv2_rw_m',
#  'efficientnetv2_rw_s',
#  'efficientnetv2_rw_t',
#  'ens_adv_inception_resnet_v2',
#  'ese_vovnet19b_dw',
#  'ese_vovnet39b',
#  'fbnetc_100',
#  'fbnetv3_b',
#  'fbnetv3_d',
#  'fbnetv3_g',
#  'gc_efficientnetv2_rw_t',
#  'gcresnet33ts',
#  'gcresnet50t',
#  'gcresnext26ts',
#  'gcresnext50ts',
#  'gernet_l',
#  'gernet_m',
#  'gernet_s',
#  'ghostnet_100',
#  'gluon_inception_v3',
#  'gluon_resnet18_v1b',
#  'gluon_resnet34_v1b',
#  'gluon_resnet50_v1b',
#  'gluon_resnet50_v1c',
#  'gluon_resnet50_v1d',
#  'gluon_resnet50_v1s',
#  'gluon_resnet101_v1b',
#  'gluon_resnet101_v1c',
#  'gluon_resnet101_v1d',
#  'gluon_resnet101_v1s',
#  'gluon_resnet152_v1b',
#  'gluon_resnet152_v1c',
#  'gluon_resnet152_v1d',
#  'gluon_resnet152_v1s',
#  'gluon_resnext50_32x4d',
#  'gluon_resnext101_32x4d',
#  'gluon_resnext101_64x4d',
#  'gluon_senet154',
#  'gluon_seresnext50_32x4d',
#  'gluon_seresnext101_32x4d',
#  'gluon_seresnext101_64x4d',
#  'gluon_xception65',
#  'gmixer_24_224',
#  'gmlp_s16_224',
#  'halo2botnet50ts_256',
#  'halonet26t',
#  'halonet50ts',
#  'haloregnetz_b',
#  'hardcorenas_a',
#  'hardcorenas_b',
#  'hardcorenas_c',
#  'hardcorenas_d',
#  'hardcorenas_e',
#  'hardcorenas_f',
#  'hrnet_w18',
#  'hrnet_w18_small',
#  'hrnet_w18_small_v2',
#  'hrnet_w30',
#  'hrnet_w32',
#  'hrnet_w40',
#  'hrnet_w44',
#  'hrnet_w48',
#  'hrnet_w64',
#  'ig_resnext101_32x8d',
#  'ig_resnext101_32x16d',
#  'ig_resnext101_32x32d',
#  'ig_resnext101_32x48d',
#  'inception_resnet_v2',
#  'inception_v3',
#  'inception_v4',
#  'jx_nest_base',
#  'jx_nest_small',
#  'jx_nest_tiny',
#  'lambda_resnet26rpt_256',
#  'lambda_resnet26t',
#  'lambda_resnet50ts',
#  'lamhalobotnet50ts_256',
#  'lcnet_050',
#  'lcnet_075',
#  'lcnet_100',
#  'legacy_senet154',
#  'legacy_seresnet18',
#  'legacy_seresnet34',
#  'legacy_seresnet50',
#  'legacy_seresnet101',
#  'legacy_seresnet152',
#  'legacy_seresnext26_32x4d',
#  'legacy_seresnext50_32x4d',
#  'legacy_seresnext101_32x4d',
#  'levit_128',
#  'levit_128s',
#  'levit_192',
#  'levit_256',
#  'levit_384',
#  'mixer_b16_224',
#  'mixer_b16_224_in21k',
#  'mixer_b16_224_miil',
#  'mixer_b16_224_miil_in21k',
#  'mixer_l16_224',
#  'mixer_l16_224_in21k',
#  'mixnet_l',
#  'mixnet_m',
#  'mixnet_s',
#  'mixnet_xl',
#  'mnasnet_100',
#  'mnasnet_small',
#  'mobilenetv2_050',
#  'mobilenetv2_100',
#  'mobilenetv2_110d',
#  'mobilenetv2_120d',
#  'mobilenetv2_140',
#  'mobilenetv3_large_100',
#  'mobilenetv3_large_100_miil',
#  'mobilenetv3_large_100_miil_in21k',
#  'mobilenetv3_rw',
#  'nasnetalarge',
#  'nf_regnet_b1',
#  'nf_resnet50',
#  'nfnet_l0',
#  'pit_b_224',
#  'pit_b_distilled_224',
#  'pit_s_224',
#  'pit_s_distilled_224',
#  'pit_ti_224',
#  'pit_ti_distilled_224',
#  'pit_xs_224',
#  'pit_xs_distilled_224',
#  'pnasnet5large',
#  'regnetx_002',
#  'regnetx_004',
#  'regnetx_006',
#  'regnetx_008',
#  'regnetx_016',
#  'regnetx_032',
#  'regnetx_040',
#  'regnetx_064',
#  'regnetx_080',
#  'regnetx_120',
#  'regnetx_160',
#  'regnetx_320',
#  'regnety_002',
#  'regnety_004',
#  'regnety_006',
#  'regnety_008',
#  'regnety_016',
#  'regnety_032',
#  'regnety_040',
#  'regnety_064',
#  'regnety_080',
#  'regnety_120',
#  'regnety_160',
#  'regnety_320',
#  'regnetz_b16',
#  'regnetz_c16',
#  'regnetz_d8',
#  'regnetz_d32',
#  'regnetz_e8',
#  'repvgg_a2',
#  'repvgg_b0',
#  'repvgg_b1',
#  'repvgg_b1g4',
#  'repvgg_b2',
#  'repvgg_b2g4',
#  'repvgg_b3',
#  'repvgg_b3g4',
#  'res2net50_14w_8s',
#  'res2net50_26w_4s',
#  'res2net50_26w_6s',
#  'res2net50_26w_8s',
#  'res2net50_48w_2s',
#  'res2net101_26w_4s',
#  'res2next50',
#  'resmlp_12_224',
#  'resmlp_12_224_dino',
#  'resmlp_12_distilled_224',
#  'resmlp_24_224',
#  'resmlp_24_224_dino',
#  'resmlp_24_distilled_224',
#  'resmlp_36_224',
#  'resmlp_36_distilled_224',
#  'resmlp_big_24_224',
#  'resmlp_big_24_224_in22ft1k',
#  'resmlp_big_24_distilled_224',
#  'resnest14d',
#  'resnest26d',
#  'resnest50d',
#  'resnest50d_1s4x24d',
#  'resnest50d_4s2x40d',
#  'resnest101e',
#  'resnest200e',
#  'resnest269e',
#  'resnet18',
#  'resnet18d',
#  'resnet26',
#  'resnet26d',
#  'resnet26t',
#  'resnet32ts',
#  'resnet33ts',
#  'resnet34',
#  'resnet34d',
#  'resnet50',
#  'resnet50_gn',
#  'resnet50d',
#  'resnet51q',
#  'resnet61q',
#  'resnet101',
#  'resnet101d',
#  'resnet152',
#  'resnet152d',
#  'resnet200d',
#  'resnetblur50',
#  'resnetrs50',
#  'resnetrs101',
#  'resnetrs152',
#  'resnetrs200',
#  'resnetrs270',
#  'resnetrs350',
#  'resnetrs420',
#  'resnetv2_50',
#  'resnetv2_50x1_bit_distilled',
#  'resnetv2_50x1_bitm',
#  'resnetv2_50x1_bitm_in21k',
#  'resnetv2_50x3_bitm',
#  'resnetv2_50x3_bitm_in21k',
#  'resnetv2_101',
#  'resnetv2_101x1_bitm',
#  'resnetv2_101x1_bitm_in21k',
#  'resnetv2_101x3_bitm',
#  'resnetv2_101x3_bitm_in21k',
#  'resnetv2_152x2_bit_teacher',
#  'resnetv2_152x2_bit_teacher_384',
#  'resnetv2_152x2_bitm',
#  'resnetv2_152x2_bitm_in21k',
#  'resnetv2_152x4_bitm',
#  'resnetv2_152x4_bitm_in21k',
#  'resnext26ts',
#  'resnext50_32x4d',
#  'resnext50d_32x4d',
#  'resnext101_32x8d',
#  'rexnet_100',
#  'rexnet_130',
#  'rexnet_150',
#  'rexnet_200',
#  'sebotnet33ts_256',
#  'sehalonet33ts',
#  'selecsls42b',
#  'selecsls60',
#  'selecsls60b',
#  'semnasnet_075',
#  'semnasnet_100',
#  'seresnet33ts',
#  'seresnet50',
#  'seresnet152d',
#  'seresnext26d_32x4d',
#  'seresnext26t_32x4d',
#  'seresnext26ts',
#  'seresnext50_32x4d',
#  'skresnet18',
#  'skresnet34',
#  'skresnext50_32x4d',
#  'spnasnet_100',
#  'ssl_resnet18',
#  'ssl_resnet50',
#  'ssl_resnext50_32x4d',
#  'ssl_resnext101_32x4d',
#  'ssl_resnext101_32x8d',
#  'ssl_resnext101_32x16d',
#  'swin_base_patch4_window7_224',
#  'swin_base_patch4_window7_224_in22k',
#  'swin_base_patch4_window12_384',
#  'swin_base_patch4_window12_384_in22k',
#  'swin_large_patch4_window7_224',
#  'swin_large_patch4_window7_224_in22k',
#  'swin_large_patch4_window12_384',
#  'swin_large_patch4_window12_384_in22k',
#  'swin_small_patch4_window7_224',
#  'swin_tiny_patch4_window7_224',
#  'swsl_resnet18',
#  'swsl_resnet50',
#  'swsl_resnext50_32x4d',
#  'swsl_resnext101_32x4d',
#  'swsl_resnext101_32x8d',
#  'swsl_resnext101_32x16d',
#  'tf_efficientnet_b0',
#  'tf_efficientnet_b0_ap',
#  'tf_efficientnet_b0_ns',
#  'tf_efficientnet_b1',
#  'tf_efficientnet_b1_ap',
#  'tf_efficientnet_b1_ns',
#  'tf_efficientnet_b2',
#  'tf_efficientnet_b2_ap',
#  'tf_efficientnet_b2_ns',
#  'tf_efficientnet_b3',
#  'tf_efficientnet_b3_ap',
#  'tf_efficientnet_b3_ns',
#  'tf_efficientnet_b4',
#  'tf_efficientnet_b4_ap',
#  'tf_efficientnet_b4_ns',
#  'tf_efficientnet_b5',
#  'tf_efficientnet_b5_ap',
#  'tf_efficientnet_b5_ns',
#  'tf_efficientnet_b6',
#  'tf_efficientnet_b6_ap',
#  'tf_efficientnet_b6_ns',
#  'tf_efficientnet_b7',
#  'tf_efficientnet_b7_ap',
#  'tf_efficientnet_b7_ns',
#  'tf_efficientnet_b8',
#  'tf_efficientnet_b8_ap',
#  'tf_efficientnet_cc_b0_4e',
#  'tf_efficientnet_cc_b0_8e',
#  'tf_efficientnet_cc_b1_8e',
#  'tf_efficientnet_el',
#  'tf_efficientnet_em',
#  'tf_efficientnet_es',
#  'tf_efficientnet_l2_ns',
#  'tf_efficientnet_l2_ns_475',
#  'tf_efficientnet_lite0',
#  'tf_efficientnet_lite1',
#  'tf_efficientnet_lite2',
#  'tf_efficientnet_lite3',
#  'tf_efficientnet_lite4',
#  'tf_efficientnetv2_b0',
#  'tf_efficientnetv2_b1',
#  'tf_efficientnetv2_b2',
#  'tf_efficientnetv2_b3',
#  'tf_efficientnetv2_l',
#  'tf_efficientnetv2_l_in21ft1k',
#  'tf_efficientnetv2_l_in21k',
#  'tf_efficientnetv2_m',
#  'tf_efficientnetv2_m_in21ft1k',
#  'tf_efficientnetv2_m_in21k',
#  'tf_efficientnetv2_s',
#  'tf_efficientnetv2_s_in21ft1k',
#  'tf_efficientnetv2_s_in21k',
#  'tf_efficientnetv2_xl_in21ft1k',
#  'tf_efficientnetv2_xl_in21k',
#  'tf_inception_v3',
#  'tf_mixnet_l',
#  'tf_mixnet_m',
#  'tf_mixnet_s',
#  'tf_mobilenetv3_large_075',
#  'tf_mobilenetv3_large_100',
#  'tf_mobilenetv3_large_minimal_100',
#  'tf_mobilenetv3_small_075',
#  'tf_mobilenetv3_small_100',
#  'tf_mobilenetv3_small_minimal_100',
#  'tinynet_a',
#  'tinynet_b',
#  'tinynet_c',
#  'tinynet_d',
#  'tinynet_e',
#  'tnt_s_patch16_224',
#  'tresnet_l',
#  'tresnet_l_448',
#  'tresnet_m',
#  'tresnet_m_448',
#  'tresnet_m_miil_in21k',
#  'tresnet_xl',
#  'tresnet_xl_448',
#  'tv_densenet121',
#  'tv_resnet34',
#  'tv_resnet50',
#  'tv_resnet101',
#  'tv_resnet152',
#  'tv_resnext50_32x4d',
#  'twins_pcpvt_base',
#  'twins_pcpvt_large',
#  'twins_pcpvt_small',
#  'twins_svt_base',
#  'twins_svt_large',
#  'twins_svt_small',
#  'vgg11',
#  'vgg11_bn',
#  'vgg13',
#  'vgg13_bn',
#  'vgg16',
#  'vgg16_bn',
#  'vgg19',
#  'vgg19_bn',
#  'visformer_small',
#  'vit_base_patch8_224',
#  'vit_base_patch8_224_in21k',
#  'vit_base_patch16_224',
#  'vit_base_patch16_224_in21k',
#  'vit_base_patch16_224_miil',
#  'vit_base_patch16_224_miil_in21k',
#  'vit_base_patch16_384',
#  'vit_base_patch16_sam_224',
#  'vit_base_patch32_224',
#  'vit_base_patch32_224_in21k',
#  'vit_base_patch32_384',
#  'vit_base_patch32_sam_224',
#  'vit_base_r50_s16_224_in21k',
#  'vit_base_r50_s16_384',
#  'vit_huge_patch14_224_in21k',
#  'vit_large_patch16_224',
#  'vit_large_patch16_224_in21k',
#  'vit_large_patch16_384',
#  'vit_large_patch32_224_in21k',
#  'vit_large_patch32_384',
#  'vit_large_r50_s32_224',
#  'vit_large_r50_s32_224_in21k',
#  'vit_large_r50_s32_384',
#  'vit_small_patch16_224',
#  'vit_small_patch16_224_in21k',
#  'vit_small_patch16_384',
#  'vit_small_patch32_224',
#  'vit_small_patch32_224_in21k',
#  'vit_small_patch32_384',
#  'vit_small_r26_s32_224',
#  'vit_small_r26_s32_224_in21k',
#  'vit_small_r26_s32_384',
#  'vit_tiny_patch16_224',
#  'vit_tiny_patch16_224_in21k',
#  'vit_tiny_patch16_384',
#  'vit_tiny_r_s16_p8_224',
#  'vit_tiny_r_s16_p8_224_in21k',
#  'vit_tiny_r_s16_p8_384',
#  'wide_resnet50_2',
#  'wide_resnet101_2',
#  'xception',
#  'xception41',
#  'xception65',
#  'xception71',
#  'xcit_large_24_p8_224',
#  'xcit_large_24_p8_224_dist',
#  'xcit_large_24_p8_384_dist',
#  'xcit_large_24_p16_224',
#  'xcit_large_24_p16_224_dist',
#  'xcit_large_24_p16_384_dist',
#  'xcit_medium_24_p8_224',
#  'xcit_medium_24_p8_224_dist',
#  'xcit_medium_24_p8_384_dist',
#  'xcit_medium_24_p16_224',
#  'xcit_medium_24_p16_224_dist',
#  'xcit_medium_24_p16_384_dist',
#  'xcit_nano_12_p8_224',
#  'xcit_nano_12_p8_224_dist',
#  'xcit_nano_12_p8_384_dist',
#  'xcit_nano_12_p16_224',
#  'xcit_nano_12_p16_224_dist',
#  'xcit_nano_12_p16_384_dist',
#  'xcit_small_12_p8_224',
#  'xcit_small_12_p8_224_dist',
#  'xcit_small_12_p8_384_dist',
#  'xcit_small_12_p16_224',
#  'xcit_small_12_p16_224_dist',
#  'xcit_small_12_p16_384_dist',
#  'xcit_small_24_p8_224',
#  'xcit_small_24_p8_224_dist',
#  'xcit_small_24_p8_384_dist',
#  'xcit_small_24_p16_224',
#  'xcit_small_24_p16_224_dist',
#  'xcit_small_24_p16_384_dist',
#  'xcit_tiny_12_p8_224',
#  'xcit_tiny_12_p8_224_dist',
#  'xcit_tiny_12_p8_384_dist',
#  'xcit_tiny_12_p16_224',
#  'xcit_tiny_12_p16_224_dist',
#  'xcit_tiny_12_p16_384_dist',
#  'xcit_tiny_24_p8_224',
#  'xcit_tiny_24_p8_224_dist',
#  'xcit_tiny_24_p8_384_dist',
#  'xcit_tiny_24_p16_224',
#  'xcit_tiny_24_p16_224_dist',
#  'xcit_tiny_24_p16_384_dist']

# %% [markdown]
# ## ConvNeXt

# %%
device = 'cuda'

model = timm.create_model('convnext_tiny', pretrained=True, num_classes=2).to(device)
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_tiny_1k_224_ema.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny_1k_224_ema.pth

# %%
model
# Out:
# ConvNeXt(
#   (stem): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#     (1): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#   )
#   (stages): Sequential(
#     (0): ConvNeXtStage(
#       (downsample): Identity()
#       (blocks): Sequential(
#         (0): ConvNeXtBlock(
#           (conv_dw): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=384, out_features=96, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (1): ConvNeXtBlock(
#           (conv_dw): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=384, out_features=96, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (2): ConvNeXtBlock(
#           (conv_dw): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=96, out_features=384, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=384, out_features=96, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#     (1): ConvNeXtStage(
#       (downsample): Sequential(
#         (0): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#         (1): Conv2d(96, 192, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (blocks): Sequential(
#         (0): ConvNeXtBlock(
#           (conv_dw): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (norm): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (1): ConvNeXtBlock(
#           (conv_dw): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (norm): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (2): ConvNeXtBlock(
#           (conv_dw): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (norm): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#     (2): ConvNeXtStage(
#       (downsample): Sequential(
#         (0): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#         (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (blocks): Sequential(
#         (0): ConvNeXtBlock(
#           (conv_dw): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (1): ConvNeXtBlock(
#           (conv_dw): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (2): ConvNeXtBlock(
#           (conv_dw): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (3): ConvNeXtBlock(
#           (conv_dw): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (4): ConvNeXtBlock(
#           (conv_dw): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (5): ConvNeXtBlock(
#           (conv_dw): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (6): ConvNeXtBlock(
#           (conv_dw): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (7): ConvNeXtBlock(
#           (conv_dw): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (8): ConvNeXtBlock(
#           (conv_dw): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#     (3): ConvNeXtStage(
#       (downsample): Sequential(
#         (0): LayerNorm2d((384,), eps=1e-06, elementwise_affine=True)
#         (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (blocks): Sequential(
#         (0): ConvNeXtBlock(
#           (conv_dw): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (1): ConvNeXtBlock(
#           (conv_dw): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#         (2): ConvNeXtBlock(
#           (conv_dw): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (act): GELU()
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path): Identity()
#         )
#       )
#     )
#   )
#   (norm_pre): Identity()
#   (head): Sequential(
#     (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Identity())
#     (norm): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (drop): Dropout(p=0.0, inplace=False)
#     (fc): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ### Training

# %%
# loss function
criterion = nn.CrossEntropyLoss()
# optimizer
optimizer = optim.Adam(model.parameters(), lr=lr)
# scheduler
scheduler = StepLR(optimizer, step_size=1, gamma=gamma)

n_epochs_stop = 3

min_val_loss = 10

# %%
epoch_l = []
loss_l = []
acc_l = []
v_loss_l = []
v_acc_l = []

# %%
since = time.time()
for epoch in range(epochs):
    epoch_loss = 0
    epoch_accuracy = 0

    for data, label in tqdm(train_loader):
        data = data.to(device)
        label = label.to(device)

        output = model(data)
        loss = criterion(output, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (output.argmax(dim=1) == label).float().mean()
        epoch_accuracy += acc / len(train_loader)
        epoch_loss += loss / len(train_loader)

    with torch.no_grad():
        epoch_val_accuracy = 0
        epoch_val_loss = 0
        for data, label in valid_loader:
            data = data.to(device)
            label = label.to(device)

            val_output = model(data)
            val_loss = criterion(val_output, label)

            acc = (val_output.argmax(dim=1) == label).float().mean()
            epoch_val_accuracy += acc / len(valid_loader)
            epoch_val_loss += val_loss / len(valid_loader)
        
        epoch_l.append(epoch+1)
        loss_l.append(epoch_loss)
        acc_l.append(epoch_accuracy)
        v_loss_l.append(epoch_val_loss)
        v_acc_l.append(epoch_val_accuracy)
        
        print(f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - acc: {epoch_accuracy:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f}\n")
        
        if epoch_val_loss < min_val_loss:
            # Saving the model
            best_model = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0
            min_val_loss = epoch_val_loss
            early_stoped = False

        else:
            epochs_no_improve += 1
            # Check early stopping condition
            if epochs_no_improve == n_epochs_stop:
                print('Early stopping!' )
                model.load_state_dict(best_model)
                early_stoped = True
                break
    if early_stoped:
        break

elapsed_time = time.time() - since
print("Training completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
# Out:
#   0%|          | 0/302 [00:00<?, ?it/s]
# Epoch : 1 - loss : 0.1539 - acc: 0.9420 - val_loss : 0.0450 - val_acc: 0.9827
#   0%|          | 0/302 [00:00<?, ?it/s]
# Epoch : 2 - loss : 0.0302 - acc: 0.9899 - val_loss : 0.0302 - val_acc: 0.9885
#   0%|          | 0/302 [00:00<?, ?it/s]
# Epoch : 3 - loss : 0.0117 - acc: 0.9966 - val_loss : 0.0202 - val_acc: 0.9942
#   0%|          | 0/302 [00:00<?, ?it/s]
# Epoch : 4 - loss : 0.0055 - acc: 0.9980 - val_loss : 0.0176 - val_acc: 0.9918
#   0%|          | 0/302 [00:00<?, ?it/s]
# Epoch : 5 - loss : 0.0078 - acc: 0.9974 - val_loss : 0.0122 - val_acc: 0.9967
#   0%|          | 0/302 [00:00<?, ?it/s]
# Epoch : 6 - loss : 0.0006 - acc: 1.0000 - val_loss : 0.0114 - val_acc: 0.9975
#   0%|          | 0/302 [00:00<?, ?it/s]
# Epoch : 7 - loss : 0.0002 - acc: 1.0000 - val_loss : 0.0128 - val_acc: 0.9984
#   0%|          | 0/302 [00:00<?, ?it/s]
# Epoch : 8 - loss : 0.0001 - acc: 1.0000 - val_loss : 0.0139 - val_acc: 0.9984
#   0%|          | 0/302 [00:00<?, ?it/s]
# Epoch : 9 - loss : 0.0001 - acc: 1.0000 - val_loss : 0.0142 - val_acc: 0.9984
#
# Early stopping!
# Training completed in 73m 19s

# %%
torch.save(model, './convnext_tiny_model_pretrained.pt')

# %% [markdown]
# ### Testing

# %%
since = time.time()

y_pred_list = []
y_true_list = []
with torch.no_grad():
    for x_batch, y_batch in tqdm(test_loader):
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        y_test_pred = model(x_batch)
        _, y_pred_tag = torch.max(y_test_pred, dim = 1)
        y_pred_list.append(y_pred_tag.cpu().numpy())
        y_true_list.append(y_batch.cpu().numpy())

def flatten(new:list, target:list):
    for li in target:
        for value in list(li):
            new.append(value)

y_pred = []
y_true = []
flatten(y_pred, y_pred_list)
flatten(y_true, y_true_list)

elapsed_time = time.time() - since
print("Evaluation completed in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
# Out:
#   0%|          | 0/38 [00:00<?, ?it/s]
# Evaluation completed in 0m 22s

# %%
from sklearn.metrics import accuracy_score, f1_score, log_loss
print("Overall accuracy:", accuracy_score(y_true, y_pred))
print("Overall F1:", f1_score(y_true, y_pred, average='weighted'))
print("Overall Loss:", log_loss(y_true, y_pred))
# Out:
# Overall accuracy: 0.9950248756218906
# Overall F1: 0.9950173547910853
# Overall Loss: 0.1718373604968375

# %%
from sklearn.metrics import precision_recall_fscore_support as score

precision, recall, fscore, support = score(y_true, y_pred)

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
print('fscore: {}'.format(fscore))
print('support: {}'.format(support))
# Out:
# precision: [0.99183673 0.99583767]
# recall: [0.98380567 0.99791449]
# fscore: [0.98780488 0.996875  ]
# support: [247 959]

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
import seaborn as sns

def plot_cm(y_true, y_pred, figsize=(10,9)):
    cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, cmap= "YlGnBu", annot=annot, fmt='', ax=ax)

plot_cm(y_true, y_pred)

display()

# %%
loss_l_c = []
acc_l_c = []
v_loss_l_c = []
v_acc_l_c = []
for x in loss_l:
    x = x.cpu().detach().numpy()
    loss_l_c.append(x)
for x in acc_l:
    x = x.cpu().detach().numpy()
    acc_l_c.append(x)
for x in v_loss_l:
    x = x.cpu().detach().numpy()
    v_loss_l_c.append(x)
for x in v_acc_l:
    x = x.cpu().detach().numpy()
    v_acc_l_c.append(x)

# %%
import plotly.graph_objects as go

# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=epoch_l, y=loss_l_c,
                    mode='lines+markers',
                    name='Train loss'))
fig.add_trace(go.Scatter(x=epoch_l, y=acc_l_c,
                    mode='lines+markers',
                    name='Train accuracy'))
fig.add_trace(go.Scatter(x=epoch_l, y=v_loss_l_c,
                    mode='lines+markers',
                    name='Validation loss'))
fig.add_trace(go.Scatter(x=epoch_l, y=v_acc_l_c,
                    mode='lines+markers',
                    name='Validation accuracy'))
fig.update_layout(
    title='convnext_tiny (pre-trained)',
    autosize=False,
    width=1000,
    height=600,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="685a070b-3423-46de-8146-0b53736f84cc" class="plotly-graph-div" style="height:600px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("685a070b-3423-46de-8146-0b53736f84cc")) {
#                     Plotly.newPlot(
#                         '685a070b-3423-46de-8146-0b53736f84cc',
#                         [{"mode": "lines+markers", "name": "Train loss", "type": "scatter", "x": [1, 2, 3, 4, 5, 6, 7, 8, 9], "y": [0.15386401116847992, 0.030156295746564865, 0.01166233979165554, 0.005470690783113241, 0.007810179144144058, 0.0006422249134629965, 0.00020433706231415272, 0.00012923008762300014, 9.377974492963403e-05]}, {"mode": "lines+markers", "name": "Train accuracy", "type": "scatter", "x": [1, 2, 3, 4, 5, 6, 7, 8, 9], "y": [0.9420256614685059, 0.9898614883422852, 0.996587336063385, 0.9980360269546509, 0.9974151849746704, 1.0000020265579224, 1.0000020265579224, 1.0000020265579224, 1.0000020265579224]}, {"mode": "lines+markers", "name": "Validation loss", "type": "scatter", "x": [1, 2, 3, 4, 5, 6, 7, 8, 9], "y": [0.04496949538588524, 0.030227746814489365, 0.020171809941530228, 0.017557216808199883, 0.012162838131189346, 0.011381763033568859, 0.012827245518565178, 0.013891374692320824, 0.0142098069190979]}, {"mode": "lines+markers", "name": "Validation accuracy", "type": "scatter", "x": [1, 2, 3, 4, 5, 6, 7, 8, 9], "y": [0.9827305674552917, 0.9884871244430542, 0.9942436814308167, 0.9917765855789185, 0.9967107772827148, 0.9975331425666809, 0.998355507850647, 0.998355507850647, 0.998355507850647]}],
#                         {"autosize": false, "height": 600, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterter ...

# %% [markdown]
# ### Inference

# %%
def predict_image(image):
    image_tensor = TRANSFORM_IMG(image).float()
    image_tensor = image_tensor.unsqueeze_(0)
    input = Variable(image_tensor)
    input = input.to(device)
    output = model(input)
    index = output.data.cpu().numpy().argmax()
    return index

# %%
classes = ['COVID', 'Normal']
def get_random_images(num):
    # classes = test_data.classes
    indices = list(range(len(test_data)))
    np.random.shuffle(indices)
    idx = indices[:num]
    from torch.utils.data.sampler import SubsetRandomSampler
    sampler = SubsetRandomSampler(idx)
    loader = torch.utils.data.DataLoader(test_data, 
                   sampler=sampler, batch_size=num)
    dataiter = iter(loader)
    images, labels = dataiter.next()
    return images, labels

# %%
to_pil = transforms.ToPILImage()
images, labels = get_random_images(5)
fig=plt.figure(figsize=(20,10))
for ii in range(len(images)):
    image = to_pil(images[ii])
    index = predict_image(image)
    sub = fig.add_subplot(1, len(images), ii+1)
    res = int(labels[ii]) == index
    sub.set_title(str(classes[index]) + " : " + str(res))
    plt.axis('off')
    plt.imshow(image)
plt.show()
